# %% [markdown]
# ## total modules
#
# 1. User input (from file or text)
#
# 2. AI logic for extracting amount, date, category
#
# 3. Store it in a local database (SQLite)
#
# 4. See a monthly summary using charts
#
# <br />
#
# ✅ STEP 1: Let's Define What We Want This Version To Do
# We’ll begin with these 3 user stories:
#
# 📌 User Story 1: Add an Expense (Text Input)
# User enters:
# "Paid 1200 to Jio on 5 August for WiFi"
#
# System detects:
#
# Amount: 1200
#
# Date: 2025-08-05
#
# Category: "WiFi Recharge" (based on keyword match or ML)
#
# Description: "Paid to Jio"
#
# Stores in database.
#
# 📌 User Story 2: Import from File
# CSV file with lines like:
#
# vbnet
# Copy
# Edit
# Date,Amount,Description
# ,3500,Loan to ICICI
# ,800,Grocery shopping
# Aug 2,600,Electricity bill
# System will:
#
# Parse each row
#
# Detect missing date and infer today’s or estimate
#
# Categorize based on description
#
# Save all to DB
#
# 📌 User Story 3: Show Monthly Summary
# User runs command: show summary for August
#
# System shows:
#
# Total spent
#
# Breakdown by category (EMI, Grocery, Recharge, etc.)
#
# Chart (bar/pie)
#
# ✅ First Goal: Build User Story 1 — Text Expense Input
